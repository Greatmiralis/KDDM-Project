# %%
from Dataloader import load_characters

heroes, villains = load_characters("Data-20250331/data.csv")
# Out:
# number all entries = 1041
# number of loaded characters = 1036

# %%
valid_chars = [c for c in heroes if c.speed != -1]
print(min(valid_chars, key=lambda x: x.speed).speed)
# Out:
# 683.0

# %%
import Data_visualizer as vis

# %%
vis.visualize_dependancy(heroes.copy(), "power_level", "win_prob")

# %%
# importance of each feature

vis.visualize_dependancy(heroes.copy(), "skin_type", "win_prob")
vis.visualize_dependancy(heroes.copy(), "power_level", "win_prob")
vis.visualize_dependancy(heroes.copy(), "weight", "win_prob")
vis.visualize_dependancy(heroes.copy(), "height", "win_prob")
vis.visualize_dependancy(heroes.copy(), "age", "win_prob")
vis.visualize_dependancy(heroes.copy(), "eye_color", "win_prob")
vis.visualize_dependancy(heroes.copy(), "gender", "win_prob")
vis.visualize_dependancy(heroes.copy(), "hair_color", "win_prob")
vis.visualize_dependancy(heroes.copy(), "speed", "win_prob")
vis.visualize_dependancy(heroes.copy(), "universe", "win_prob")
vis.visualize_dependancy(heroes.copy(), "body_type", "win_prob")
vis.visualize_dependancy(heroes.copy(), "job", "win_prob")
vis.visualize_dependancy(heroes.copy(), "battle_iq", "win_prob")
vis.visualize_dependancy(heroes.copy(), "species", "win_prob")
vis.visualize_dependancy(heroes.copy(), "ranking", "win_prob")
vis.visualize_dependancy(heroes.copy(), "intelligence", "win_prob")
vis.visualize_dependancy(heroes.copy(), "abilities", "win_prob")
vis.visualize_dependancy(heroes.copy(), "training_time", "win_prob")
vis.visualize_dependancy(heroes.copy(), "special_attack", "win_prob")
vis.visualize_dependancy(heroes.copy(), "secret_code", "win_prob")

# %%
# cross dependency

vis.visualize_dependancy(heroes.copy(), "height", "species")
vis.visualize_dependancy(heroes.copy(), "weight", "species")
vis.visualize_dependancy(heroes.copy(), "ranking", "power_level")
vis.visualize_dependancy(heroes.copy(), "species", "ranking")
vis.visualize_dependancy(heroes.copy(), "species", "power_level")
vis.visualize_dependancy(heroes.copy(), "species", "win_prob")
